# %%
import csv
import collections

def _get_example_objects(annon_filepath):
    """Function to get all the objects from the annotation CSV file."""
    with tf.io.gfile.GFile(annon_filepath, "r") as f:
        
        root = xml.etree.ElementTree.parse(f).getroot()
        
        size = root.find("size")
        width = float(size.find("width").text)
        height = float(size.find("height").text)

        for obj in root.findall("object"):
            # Get object's label name.
            label = obj.find("name").text.lower()
            # Get objects' pose name.
            pose = obj.find("pose").text.lower()
            is_truncated = (obj.find("truncated").text == "1")
            is_difficult = (obj.find("difficult").text == "1")
            bndbox = obj.find("bndbox")
            xmax = float(bndbox.find("xmax").text)
            xmin = float(bndbox.find("xmin").text)
            ymax = float(bndbox.find("ymax").text)
            ymin = float(bndbox.find("ymin").text)
            yield {
              "label": label,
              "pose": pose,
              "bbox": tfds.features.BBox(
                  ymin / height, xmin / width, ymax / height, xmax / width),
            }
    # pytype: enable=attribute-error

# %%
import logging
import collections
import csv

_Bbox = collections.namedtuple('Bbox', [
    'label', 'source', 'bbox',])


def _load_bboxes(csv_path, csv_positions, prefix):
    """Returns bounded boxes listed within given CSV file."""
    logging.info('Loading CSVs %s from positions %s with prefix %s',
               csv_path, csv_positions, prefix)
    boxes = collections.defaultdict(list)
    with tf.io.gfile.GFile(csv_path) as csv_f:
        if csv_positions[0] > 0:
            csv_f.seek(csv_positions[0])
        else:
            csv_f.readline()  # Drop headers
        #csv_f.readline()
        reader = csv.reader(csv_f)
    i = 0
    for (filename, width, height, classes, xmin, ymin, xmax, ymax) in reader:
        if filename == 'fileName':
            break
#         csv_positions[0] = csv_f.tell()
#         image_id = int(image_id, 16)
#         del confidence  # always 1 in bounding boxes.
        print(filename)
        current_row = _Bbox(
          classes, filename, tfds.features.BBox(
              float(ymin), float(xmin), float(ymax), float(xmax)))
        boxes[i].append(current_row)
        i = i + 1
    return dict(boxes)

# %%
_load_bboxes('./dataset/excel/comptech_train.csv', [22:55], 'fileName')
# Out:
#   File "<ipython-input-67-9cf02bfd9304>", line 1
#     _load_bboxes('./dataset/excel/comptech_train.csv', [22:55], 'fileName')
#                                                           ^
# SyntaxError: invalid syntax

# %%
import numpy
numpy.random.choice(numpy.arange(1, 7), p=[0.1, 0.05, 0.05, 0.2, 0.4, 0.2])
# Out:
# 4

# %%
"""Texture tiles from colorectal cancer histology."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import numpy as np
import tensorflow.compat.v2 as tf

from PIL import Image
import tensorflow_datasets.public_api as tfds


_TILES_DL_URL = "dataset/slice_data_on_folders/both.zip"
_TILES_SUBDIR = "dataset/slice_data_on_folders/both"

_CLASS_NAME = (
    "wings",
)

_TILES_SIZE = 1920
_TILES_SIZE_WIDTH = 1080

# Load image in numpy array
def _load_tif(path):
    with tf.io.gfile.GFile(path, "rb") as fp:
        image = tfds.core.lazy_imports.PIL_Image.open(fp)
    return np.array(image)


class WingsDataset(tfds.core.GeneratorBasedBuilder):
    """Detection Wings On Images."""
    VERSION = tfds.core.Version(
      "2.0.0", "New split API (https://tensorflow.org/datasets/splits)")
    SUPPORTED_VERSIONS = [
      tfds.core.Version("0.0.1",
                        experiments={tfds.core.Experiment.S3: False}),
    ]

    def _info(self):
        return tfds.core.DatasetInfo(
            builder=self,
            description=(
                "Classification of textures in colorectal cancer histology. "
                "Each example is a 1920 x 1080 x 3 RGB image of one of 1 classes."),
            features=tfds.features.FeaturesDict({
                "image": tfds.features.Image(shape=(_TILES_SIZE, _TILES_SIZE_WIDTH) + (3,)),
                "filename": tfds.features.Text(),
                "objects": tfds.features.Sequence({
                    "label": tfds.features.ClassLabel(names=_CLASS_NAME),
                    "bbox": tfds.features.BBoxFeature()
                }),
            }),
            supervised_keys=("image", "label"),
        )
    
    def _split_generators(self):
        pass
    
    def _generate_examples(self, root_dir):
        print('a')
        root_dir = os.path.join(root_dir, _TILES_SUBDIR)
        print(root_dir)
        for i, class_name in enumerate(_CLASS_NAME):
            fns = tf.io.gfile.listdir(root_dir)
            for fn in sorted(fns):
                image = _load_tif(os.path.join(root_dir, fn))
                record = {
                    "image": image,
                #                 "label": class_name,
                    "filename": fn,

                }
                yield "%s/%s" % (class_name, fn), record

    def _generate_example(self, data_path, image_id, load_annotations):
        image_filepath = os.path.join(
            data_path,
            os.path.normpath("VOCdevkit/VOC{}/JPEGImages/{}.jpg".format(
                self.builder_config.year, image_id)))

        annon_filepath = os.path.join(
            data_path,
            os.path.normpath("VOCdevkit/VOC{}/Annotations/{}.xml".format(
                self.builder_config.year, image_id)))
        if load_annotations:
            objects = list(_get_example_objects(annon_filepath))
            # Use set() to remove duplicates
            labels = sorted(set(obj["label"] for obj in objects))
        else:  # The test set of VOC2012 does not contain annotations
            objects = []
            labels = []
            
        return {
            "image": image_filepath,
            "image/filename": image_id + ".jpg",
            "objects": objects,
            "labels": labels,
            "labels_no_difficult": labels_no_difficult,
        }

# %%
dataset = WingsDataset()

# %%
dataset.info
# Out:
# tfds.core.DatasetInfo(
#     name='wings_dataset',
#     version=2.0.0,
#     description='Classification of textures in colorectal cancer histology. Each example is a 150 x 150 x 3 RGB image of one of 8 classes.',
#     homepage='https://www.tensorflow.org/datasets/catalog/wings_dataset',
#     features=FeaturesDict({
#         'filename': Text(shape=(), dtype=tf.string),
#         'image': Image(shape=(1920, 1080, 3), dtype=tf.uint8),
#         'objects': Sequence({
#             'bbox': BBoxFeature(shape=(4,), dtype=tf.float32),
#             'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=1),
#         }),
#     }),
#     total_num_examples=0,
#     splits={
#     },
#     supervised_keys=('image', 'label'),
#     citation="""""",
#     redistribution_info=,
# )

# %%
a = dataset._generate_examples('./')
for i in a:
    print(i)
# Out:
# a
# ./dataset/slice_data_on_folders/both
# source1_001.bmp
# ('wings/source1_001.bmp', {'image': array([[[145, 145, 145],
#         [145, 145, 145],
#         [144, 144, 144],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[147, 147, 147],
#         [147, 147, 147],
#         [146, 146, 146],
#         ...,
#         [121, 121, 121],
#         [121, 121, 121],
#         [121, 121, 121]],
#
#        [[149, 149, 149],
#         [148, 148, 148],
#         [147, 147, 147],
#         ...,
#         [124, 124, 124],
#         [124, 124, 124],
#         [124, 124, 124]],
#
#        ...,
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [182, 182, 182],
#         [181, 181, 181],
#         [180, 180, 180]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [180, 180, 180],
#         [181, 181, 181],
#         [181, 181, 181]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [182, 182, 182],
#         [182, 182, 182],
#         [183, 183, 183]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_001.bmp'})
# source1_002.bmp
# ('wings/source1_002.bmp', {'image': array([[[147, 147, 147],
#         [149, 149, 149],
#         [149, 149, 149],
#         ...,
#         [130, 130, 130],
#         [131, 131, 131],
#         [132, 132, 132]],
#
#        [[148, 148, 148],
#         [149, 149, 149],
#         [148, 148, 148],
#         ...,
#         [125, 125, 125],
#         [124, 124, 124],
#         [124, 124, 124]],
#
#        [[147, 147, 147],
#         [148, 148, 148],
#         [147, 147, 147],
#         ...,
#         [125, 125, 125],
#         [122, 122, 122],
#         [119, 119, 119]],
#
#        ...,
#
#        [[134, 134, 134],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [185, 185, 185],
#         [189, 189, 189],
#         [177, 177, 177]],
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [178, 178, 178],
#         [188, 188, 188],
#         [183, 183, 183]],
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [181, 181, 181],
#         [189, 189, 189],
#         [183, 183, 183]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_002.bmp'})
# source1_003.bmp
# ('wings/source1_003.bmp', {'image': array([[[143, 143, 143],
#         [145, 145, 145],
#         [147, 147, 147],
#         ...,
#         [133, 133, 133],
#         [130, 130, 130],
#         [126, 126, 126]],
#
#        [[145, 145, 145],
#         [146, 146, 146],
#         [150, 150, 150],
#         ...,
#         [127, 127, 127],
#         [128, 128, 128],
#         [126, 126, 126]],
#
#        [[147, 147, 147],
#         [149, 149, 149],
#         [153, 153, 153],
#         ...,
#         [121, 121, 121],
#         [121, 121, 121],
#         [120, 120, 120]],
#
#        ...,
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [185, 185, 185],
#         [186, 186, 186],
#         [186, 186, 186]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [183, 183, 183],
#         [183, 183, 183],
#         [187, 187, 187]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [186, 186, 186],
#         [185, 185, 185],
#         [189, 189, 189]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_003.bmp'})
# source1_004.bmp
# ('wings/source1_004.bmp', {'image': array([[[144, 144, 144],
#         [145, 145, 145],
#         [145, 145, 145],
#         ...,
#         [135, 135, 135],
#         [131, 131, 131],
#         [125, 125, 125]],
#
#        [[146, 146, 146],
#         [147, 147, 147],
#         [146, 146, 146],
#         ...,
#         [133, 133, 133],
#         [129, 129, 129],
#         [122, 122, 122]],
#
#        [[148, 148, 148],
#         [149, 149, 149],
#         [147, 147, 147],
#         ...,
#         [131, 131, 131],
#         [129, 129, 129],
#         [123, 123, 123]],
#
#        ...,
#
#        [[136, 136, 136],
#         [137, 137, 137],
#         [138, 138, 138],
#         ...,
#         [179, 179, 179],
#         [186, 186, 186],
#         [183, 183, 183]],
#
#        [[132, 132, 132],
#         [143, 143, 143],
#         [142, 142, 142],
#         ...,
#         [180, 180, 180],
#         [185, 185, 185],
#         [185, 185, 185]],
#
#        [[132, 132, 132],
#         [143, 143, 143],
#         [142, 142, 142],
#         ...,
#         [182, 182, 182],
#         [186, 186, 186],
#         [185, 185, 185]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_004.bmp'})
# source1_005.bmp
# ('wings/source1_005.bmp', {'image': array([[[142, 142, 142],
#         [144, 144, 144],
#         [146, 146, 146],
#         ...,
#         [132, 132, 132],
#         [133, 133, 133],
#         [126, 126, 126]],
#
#        [[146, 146, 146],
#         [150, 150, 150],
#         [151, 151, 151],
#         ...,
#         [128, 128, 128],
#         [126, 126, 126],
#         [119, 119, 119]],
#
#        [[148, 148, 148],
#         [154, 154, 154],
#         [155, 155, 155],
#         ...,
#         [124, 124, 124],
#         [122, 122, 122],
#         [114, 114, 114]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [180, 180, 180],
#         [188, 188, 188],
#         [182, 182, 182]],
#
#        [[135, 135, 135],
#         [134, 134, 134],
#         [138, 138, 138],
#         ...,
#         [186, 186, 186],
#         [189, 189, 189],
#         [182, 182, 182]],
#
#        [[135, 135, 135],
#         [134, 134, 134],
#         [138, 138, 138],
#         ...,
#         [187, 187, 187],
#         [189, 189, 189],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_005.bmp'})
# source1_006.bmp
# ('wings/source1_006.bmp', {'image': array([[[140, 140, 140],
#         [143, 143, 143],
#         [145, 145, 145],
#         ...,
#         [133, 133, 133],
#         [129, 129, 129],
#         [121, 121, 121]],
#
#        [[143, 143, 143],
#         [148, 148, 148],
#         [150, 150, 150],
#         ...,
#         [125, 125, 125],
#         [123, 123, 123],
#         [117, 117, 117]],
#
#        [[146, 146, 146],
#         [153, 153, 153],
#         [155, 155, 155],
#         ...,
#         [124, 124, 124],
#         [123, 123, 123],
#         [118, 118, 118]],
#
#        ...,
#
#        [[134, 134, 134],
#         [133, 133, 133],
#         [132, 132, 132],
#         ...,
#         [181, 181, 181],
#         [183, 183, 183],
#         [182, 182, 182]],
#
#        [[134, 134, 134],
#         [132, 132, 132],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [181, 181, 181],
#         [180, 180, 180]],
#
#        [[133, 133, 133],
#         [131, 131, 131],
#         [134, 134, 134],
#         ...,
#         [188, 188, 188],
#         [187, 187, 187],
#         [184, 184, 184]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_006.bmp'})
# source1_007.bmp
# ('wings/source1_007.bmp', {'image': array([[[139, 139, 139],
#         [146, 146, 146],
#         [145, 145, 145],
#         ...,
#         [133, 133, 133],
#         [125, 125, 125],
#         [121, 121, 121]],
#
#        [[141, 141, 141],
#         [148, 148, 148],
#         [148, 148, 148],
#         ...,
#         [127, 127, 127],
#         [123, 123, 123],
#         [120, 120, 120]],
#
#        [[146, 146, 146],
#         [150, 150, 150],
#         [154, 154, 154],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [119, 119, 119]],
#
#        ...,
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [137, 137, 137],
#         ...,
#         [174, 174, 174],
#         [185, 185, 185],
#         [182, 182, 182]],
#
#        [[136, 136, 136],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [180, 180, 180],
#         [184, 184, 184],
#         [184, 184, 184]],
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [136, 136, 136],
#         ...,
#         [181, 181, 181],
#         [188, 188, 188],
#         [188, 188, 188]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_007.bmp'})
# source1_008.bmp
# ('wings/source1_008.bmp', {'image': array([[[142, 142, 142],
#         [143, 143, 143],
#         [144, 144, 144],
#         ...,
#         [128, 128, 128],
#         [126, 126, 126],
#         [126, 126, 126]],
#
#        [[144, 144, 144],
#         [146, 146, 146],
#         [147, 147, 147],
#         ...,
#         [124, 124, 124],
#         [122, 122, 122],
#         [118, 118, 118]],
#
#        [[148, 148, 148],
#         [149, 149, 149],
#         [151, 151, 151],
#         ...,
#         [124, 124, 124],
#         [122, 122, 122],
#         [117, 117, 117]],
#
#        ...,
#
#        [[133, 133, 133],
#         [133, 133, 133],
#         [134, 134, 134],
#         ...,
#         [176, 176, 176],
#         [182, 182, 182],
#         [182, 182, 182]],
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [173, 173, 173],
#         [180, 180, 180],
#         [176, 176, 176]],
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [187, 187, 187],
#         [178, 178, 178]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_008.bmp'})
# source1_009.bmp
# ('wings/source1_009.bmp', {'image': array([[[141, 141, 141],
#         [143, 143, 143],
#         [144, 144, 144],
#         ...,
#         [134, 134, 134],
#         [129, 129, 129],
#         [124, 124, 124]],
#
#        [[142, 142, 142],
#         [145, 145, 145],
#         [147, 147, 147],
#         ...,
#         [128, 128, 128],
#         [126, 126, 126],
#         [122, 122, 122]],
#
#        [[144, 144, 144],
#         [148, 148, 148],
#         [151, 151, 151],
#         ...,
#         [125, 125, 125],
#         [126, 126, 126],
#         [124, 124, 124]],
#
#        ...,
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [182, 182, 182],
#         [183, 183, 183],
#         [182, 182, 182]],
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [175, 175, 175],
#         [184, 184, 184],
#         [179, 179, 179]],
#
#        [[134, 134, 134],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [178, 178, 178],
#         [187, 187, 187],
#         [179, 179, 179]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_009.bmp'})
# source1_010.bmp
# ('wings/source1_010.bmp', {'image': array([[[141, 141, 141],
#         [144, 144, 144],
#         [146, 146, 146],
#         ...,
#         [134, 134, 134],
#         [127, 127, 127],
#         [125, 125, 125]],
#
#        [[142, 142, 142],
#         [146, 146, 146],
#         [149, 149, 149],
#         ...,
#         [127, 127, 127],
#         [120, 120, 120],
#         [118, 118, 118]],
#
#        [[144, 144, 144],
#         [149, 149, 149],
#         [153, 153, 153],
#         ...,
#         [123, 123, 123],
#         [120, 120, 120],
#         [119, 119, 119]],
#
#        ...,
#
#        [[133, 133, 133],
#         [133, 133, 133],
#         [134, 134, 134],
#         ...,
#         [182, 182, 182],
#         [186, 186, 186],
#         [182, 182, 182]],
#
#        [[134, 134, 134],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [181, 181, 181],
#         [185, 185, 185],
#         [182, 182, 182]],
#
#        [[134, 134, 134],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [183, 183, 183],
#         [186, 186, 186],
#         [183, 183, 183]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_010.bmp'})
# source1_011.bmp
# ('wings/source1_011.bmp', {'image': array([[[140, 140, 140],
#         [142, 142, 142],
#         [143, 143, 143],
#         ...,
#         [131, 131, 131],
#         [131, 131, 131],
#         [129, 129, 129]],
#
#        [[142, 142, 142],
#         [144, 144, 144],
#         [146, 146, 146],
#         ...,
#         [125, 125, 125],
#         [124, 124, 124],
#         [121, 121, 121]],
#
#        [[146, 146, 146],
#         [150, 150, 150],
#         [153, 153, 153],
#         ...,
#         [125, 125, 125],
#         [123, 123, 123],
#         [119, 119, 119]],
#
#        ...,
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [185, 185, 185],
#         [182, 182, 182],
#         [181, 181, 181]],
#
#        [[132, 132, 132],
#         [134, 134, 134],
#         [137, 137, 137],
#         ...,
#         [186, 186, 186],
#         [187, 187, 187],
#         [181, 181, 181]],
#
#        [[132, 132, 132],
#         [134, 134, 134],
#         [137, 137, 137],
#         ...,
#         [184, 184, 184],
#         [185, 185, 185],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_011.bmp'})
# source1_012.bmp
# ('wings/source1_012.bmp', {'image': array([[[142, 142, 142],
#         [141, 141, 141],
#         [141, 141, 141],
#         ...,
#         [130, 130, 130],
#         [128, 128, 128],
#         [124, 124, 124]],
#
#        [[146, 146, 146],
#         [147, 147, 147],
#         [148, 148, 148],
#         ...,
#         [131, 131, 131],
#         [127, 127, 127],
#         [120, 120, 120]],
#
#        [[148, 148, 148],
#         [150, 150, 150],
#         [153, 153, 153],
#         ...,
#         [123, 123, 123],
#         [124, 124, 124],
#         [120, 120, 120]],
#
#        ...,
#
#        [[133, 133, 133],
#         [133, 133, 133],
#         [134, 134, 134],
#         ...,
#         [180, 180, 180],
#         [186, 186, 186],
#         [186, 186, 186]],
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [178, 178, 178],
#         [185, 185, 185],
#         [183, 183, 183]],
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [184, 184, 184],
#         [190, 190, 190],
#         [187, 187, 187]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_012.bmp'})
# source1_013.bmp
# ('wings/source1_013.bmp', {'image': array([[[143, 143, 143],
#         [144, 144, 144],
#         [141, 141, 141],
#         ...,
#         [129, 129, 129],
#         [126, 126, 126],
#         [123, 123, 123]],
#
#        [[147, 147, 147],
#         [151, 151, 151],
#         [150, 150, 150],
#         ...,
#         [126, 126, 126],
#         [120, 120, 120],
#         [114, 114, 114]],
#
#        [[146, 146, 146],
#         [154, 154, 154],
#         [156, 156, 156],
#         ...,
#         [124, 124, 124],
#         [123, 123, 123],
#         [117, 117, 117]],
#
#        ...,
#
#        [[132, 132, 132],
#         [132, 132, 132],
#         [133, 133, 133],
#         ...,
#         [175, 175, 175],
#         [186, 186, 186],
#         [185, 185, 185]],
#
#        [[133, 133, 133],
#         [134, 134, 134],
#         [134, 134, 134],
#         ...,
#         [180, 180, 180],
#         [188, 188, 188],
#         [182, 182, 182]],
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [184, 184, 184],
#         [191, 191, 191],
#         [185, 185, 185]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_013.bmp'})
# source1_014.bmp
# ('wings/source1_014.bmp', {'image': array([[[141, 141, 141],
#         [145, 145, 145],
#         [147, 147, 147],
#         ...,
#         [131, 131, 131],
#         [127, 127, 127],
#         [124, 124, 124]],
#
#        [[142, 142, 142],
#         [147, 147, 147],
#         [150, 150, 150],
#         ...,
#         [126, 126, 126],
#         [125, 125, 125],
#         [123, 123, 123]],
#
#        [[144, 144, 144],
#         [151, 151, 151],
#         [154, 154, 154],
#         ...,
#         [122, 122, 122],
#         [123, 123, 123],
#         [122, 122, 122]],
#
#        ...,
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [184, 184, 184],
#         [182, 182, 182],
#         [181, 181, 181]],
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [138, 138, 138],
#         ...,
#         [178, 178, 178],
#         [182, 182, 182],
#         [179, 179, 179]],
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [138, 138, 138],
#         ...,
#         [181, 181, 181],
#         [186, 186, 186],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_014.bmp'})
# source1_015.bmp
# ('wings/source1_015.bmp', {'image': array([[[143, 143, 143],
#         [145, 145, 145],
#         [148, 148, 148],
#         ...,
#         [132, 132, 132],
#         [129, 129, 129],
#         [126, 126, 126]],
#
#        [[145, 145, 145],
#         [147, 147, 147],
#         [150, 150, 150],
#         ...,
#         [127, 127, 127],
#         [126, 126, 126],
#         [124, 124, 124]],
#
#        [[147, 147, 147],
#         [149, 149, 149],
#         [153, 153, 153],
#         ...,
#         [121, 121, 121],
#         [120, 120, 120],
#         [119, 119, 119]],
#
#        ...,
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [187, 187, 187],
#         [182, 182, 182]],
#
#        [[133, 133, 133],
#         [133, 133, 133],
#         [138, 138, 138],
#         ...,
#         [177, 177, 177],
#         [180, 180, 180],
#         [179, 179, 179]],
#
#        [[133, 133, 133],
#         [133, 133, 133],
#         [138, 138, 138],
#         ...,
#         [180, 180, 180],
#         [184, 184, 184],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_015.bmp'})
# source1_016.bmp
# ('wings/source1_016.bmp', {'image': array([[[145, 145, 145],
#         [143, 143, 143],
#         [142, 142, 142],
#         ...,
#         [137, 137, 137],
#         [135, 135, 135],
#         [132, 132, 132]],
#
#        [[146, 146, 146],
#         [145, 145, 145],
#         [145, 145, 145],
#         ...,
#         [132, 132, 132],
#         [131, 131, 131],
#         [127, 127, 127]],
#
#        [[146, 146, 146],
#         [147, 147, 147],
#         [149, 149, 149],
#         ...,
#         [127, 127, 127],
#         [126, 126, 126],
#         [123, 123, 123]],
#
#        ...,
#
#        [[131, 131, 131],
#         [131, 131, 131],
#         [131, 131, 131],
#         ...,
#         [179, 179, 179],
#         [184, 184, 184],
#         [181, 181, 181]],
#
#        [[131, 131, 131],
#         [131, 131, 131],
#         [131, 131, 131],
#         ...,
#         [178, 178, 178],
#         [185, 185, 185],
#         [178, 178, 178]],
#
#        [[131, 131, 131],
#         [131, 131, 131],
#         [131, 131, 131],
#         ...,
#         [184, 184, 184],
#         [191, 191, 191],
#         [183, 183, 183]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_016.bmp'})
# source1_017.bmp
# ('wings/source1_017.bmp', {'image': array([[[144, 144, 144],
#         [144, 144, 144],
#         [143, 143, 143],
#         ...,
#         [137, 137, 137],
#         [131, 131, 131],
#         [126, 126, 126]],
#
#        [[145, 145, 145],
#         [146, 146, 146],
#         [147, 147, 147],
#         ...,
#         [133, 133, 133],
#         [129, 129, 129],
#         [126, 126, 126]],
#
#        [[146, 146, 146],
#         [148, 148, 148],
#         [151, 151, 151],
#         ...,
#         [127, 127, 127],
#         [126, 126, 126],
#         [124, 124, 124]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [179, 179, 179],
#         [182, 182, 182],
#         [177, 177, 177]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [188, 188, 188],
#         [182, 182, 182]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [188, 188, 188],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_017.bmp'})
# source1_018.bmp
# ('wings/source1_018.bmp', {'image': array([[[145, 145, 145],
#         [144, 144, 144],
#         [147, 147, 147],
#         ...,
#         [137, 137, 137],
#         [135, 135, 135],
#         [130, 130, 130]],
#
#        [[145, 145, 145],
#         [145, 145, 145],
#         [148, 148, 148],
#         ...,
#         [127, 127, 127],
#         [124, 124, 124],
#         [120, 120, 120]],
#
#        [[144, 144, 144],
#         [146, 146, 146],
#         [150, 150, 150],
#         ...,
#         [119, 119, 119],
#         [119, 119, 119],
#         [122, 122, 122]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [183, 183, 183],
#         [182, 182, 182],
#         [181, 181, 181]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [182, 182, 182],
#         [192, 192, 192],
#         [180, 180, 180]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [181, 181, 181],
#         [193, 193, 193],
#         [183, 183, 183]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_018.bmp'})
# source1_019.bmp
# ('wings/source1_019.bmp', {'image': array([[[148, 148, 148],
#         [146, 146, 146],
#         [149, 149, 149],
#         ...,
#         [139, 139, 139],
#         [138, 138, 138],
#         [130, 130, 130]],
#
#        [[148, 148, 148],
#         [147, 147, 147],
#         [151, 151, 151],
#         ...,
#         [129, 129, 129],
#         [125, 125, 125],
#         [118, 118, 118]],
#
#        [[148, 148, 148],
#         [148, 148, 148],
#         [152, 152, 152],
#         ...,
#         [127, 127, 127],
#         [122, 122, 122],
#         [114, 114, 114]],
#
#        ...,
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [179, 179, 179],
#         [185, 185, 185],
#         [179, 179, 179]],
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [139, 139, 139],
#         ...,
#         [180, 180, 180],
#         [187, 187, 187],
#         [179, 179, 179]],
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [139, 139, 139],
#         ...,
#         [181, 181, 181],
#         [187, 187, 187],
#         [179, 179, 179]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_019.bmp'})
# source1_020.bmp
# ('wings/source1_020.bmp', {'image': array([[[150, 150, 150],
#         [148, 148, 148],
#         [143, 143, 143],
#         ...,
#         [136, 136, 136],
#         [132, 132, 132],
#         [125, 125, 125]],
#
#        [[148, 148, 148],
#         [149, 149, 149],
#         [147, 147, 147],
#         ...,
#         [131, 131, 131],
#         [128, 128, 128],
#         [119, 119, 119]],
#
#        [[147, 147, 147],
#         [152, 152, 152],
#         [154, 154, 154],
#         ...,
#         [125, 125, 125],
#         [124, 124, 124],
#         [114, 114, 114]],
#
#        ...,
#
#        [[140, 140, 140],
#         [139, 139, 139],
#         [137, 137, 137],
#         ...,
#         [183, 183, 183],
#         [185, 185, 185],
#         [185, 185, 185]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [137, 137, 137],
#         ...,
#         [178, 178, 178],
#         [189, 189, 189],
#         [183, 183, 183]],
#
#        [[139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139],
#         ...,
#         [179, 179, 179],
#         [189, 189, 189],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_020.bmp'})
# source1_021.bmp
# ('wings/source1_021.bmp', {'image': array([[[147, 147, 147],
#         [149, 149, 149],
#         [149, 149, 149],
#         ...,
#         [129, 129, 129],
#         [127, 127, 127],
#         [126, 126, 126]],
#
#        [[143, 143, 143],
#         [147, 147, 147],
#         [149, 149, 149],
#         ...,
#         [129, 129, 129],
#         [128, 128, 128],
#         [126, 126, 126]],
#
#        [[144, 144, 144],
#         [150, 150, 150],
#         [152, 152, 152],
#         ...,
#         [128, 128, 128],
#         [126, 126, 126],
#         [124, 124, 124]],
#
#        ...,
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [196, 196, 196],
#         [193, 193, 193],
#         [198, 198, 198]],
#
#        [[140, 140, 140],
#         [139, 139, 139],
#         [142, 142, 142],
#         ...,
#         [192, 192, 192],
#         [192, 192, 192],
#         [191, 191, 191]],
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [140, 140, 140],
#         ...,
#         [193, 193, 193],
#         [193, 193, 193],
#         [192, 192, 192]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_021.bmp'})
# source1_022.bmp
# ('wings/source1_022.bmp', {'image': array([[[142, 142, 142],
#         [143, 143, 143],
#         [145, 145, 145],
#         ...,
#         [134, 134, 134],
#         [129, 129, 129],
#         [125, 125, 125]],
#
#        [[143, 143, 143],
#         [145, 145, 145],
#         [146, 146, 146],
#         ...,
#         [127, 127, 127],
#         [123, 123, 123],
#         [119, 119, 119]],
#
#        [[146, 146, 146],
#         [148, 148, 148],
#         [149, 149, 149],
#         ...,
#         [127, 127, 127],
#         [128, 128, 128],
#         [125, 125, 125]],
#
#        ...,
#
#        [[136, 136, 136],
#         [138, 138, 138],
#         [140, 140, 140],
#         ...,
#         [184, 184, 184],
#         [181, 181, 181],
#         [182, 182, 182]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [185, 185, 185],
#         [186, 186, 186],
#         [185, 185, 185]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [185, 185, 185],
#         [186, 186, 186],
#         [186, 186, 186]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_022.bmp'})
# source1_023.bmp
# ('wings/source1_023.bmp', {'image': array([[[147, 147, 147],
#         [148, 148, 148],
#         [148, 148, 148],
#         ...,
#         [138, 138, 138],
#         [135, 135, 135],
#         [129, 129, 129]],
#
#        [[146, 146, 146],
#         [149, 149, 149],
#         [150, 150, 150],
#         ...,
#         [129, 129, 129],
#         [123, 123, 123],
#         [121, 121, 121]],
#
#        [[146, 146, 146],
#         [152, 152, 152],
#         [154, 154, 154],
#         ...,
#         [123, 123, 123],
#         [119, 119, 119],
#         [117, 117, 117]],
#
#        ...,
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [181, 181, 181],
#         [182, 182, 182],
#         [180, 180, 180]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [183, 183, 183],
#         [187, 187, 187],
#         [177, 177, 177]],
#
#        [[140, 140, 140],
#         [139, 139, 139],
#         [139, 139, 139],
#         ...,
#         [179, 179, 179],
#         [185, 185, 185],
#         [176, 176, 176]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_023.bmp'})
# source1_024.bmp
# ('wings/source1_024.bmp', {'image': array([[[145, 145, 145],
#         [148, 148, 148],
#         [148, 148, 148],
#         ...,
#         [133, 133, 133],
#         [130, 130, 130],
#         [124, 124, 124]],
#
#        [[146, 146, 146],
#         [149, 149, 149],
#         [150, 150, 150],
#         ...,
#         [129, 129, 129],
#         [127, 127, 127],
#         [122, 122, 122]],
#
#        [[147, 147, 147],
#         [150, 150, 150],
#         [152, 152, 152],
#         ...,
#         [124, 124, 124],
#         [121, 121, 121],
#         [117, 117, 117]],
#
#        ...,
#
#        [[134, 134, 134],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [182, 182, 182],
#         [182, 182, 182],
#         [183, 183, 183]],
#
#        [[137, 137, 137],
#         [136, 136, 136],
#         [135, 135, 135],
#         ...,
#         [179, 179, 179],
#         [180, 180, 180],
#         [182, 182, 182]],
#
#        [[139, 139, 139],
#         [138, 138, 138],
#         [136, 136, 136],
#         ...,
#         [180, 180, 180],
#         [181, 181, 181],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_024.bmp'})
# source1_025.bmp
# ('wings/source1_025.bmp', {'image': array([[[145, 145, 145],
#         [148, 148, 148],
#         [148, 148, 148],
#         ...,
#         [135, 135, 135],
#         [135, 135, 135],
#         [130, 130, 130]],
#
#        [[147, 147, 147],
#         [149, 149, 149],
#         [150, 150, 150],
#         ...,
#         [130, 130, 130],
#         [126, 126, 126],
#         [120, 120, 120]],
#
#        [[148, 148, 148],
#         [150, 150, 150],
#         [152, 152, 152],
#         ...,
#         [127, 127, 127],
#         [123, 123, 123],
#         [118, 118, 118]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [136, 136, 136],
#         ...,
#         [182, 182, 182],
#         [181, 181, 181],
#         [183, 183, 183]],
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [173, 173, 173],
#         [188, 188, 188],
#         [180, 180, 180]],
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [174, 174, 174],
#         [187, 187, 187],
#         [179, 179, 179]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_025.bmp'})
# source1_026.bmp
# ('wings/source1_026.bmp', {'image': array([[[144, 144, 144],
#         [144, 144, 144],
#         [145, 145, 145],
#         ...,
#         [136, 136, 136],
#         [132, 132, 132],
#         [125, 125, 125]],
#
#        [[145, 145, 145],
#         [147, 147, 147],
#         [148, 148, 148],
#         ...,
#         [127, 127, 127],
#         [121, 121, 121],
#         [113, 113, 113]],
#
#        [[146, 146, 146],
#         [150, 150, 150],
#         [151, 151, 151],
#         ...,
#         [123, 123, 123],
#         [123, 123, 123],
#         [118, 118, 118]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [181, 181, 181],
#         [178, 178, 178]],
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [174, 174, 174],
#         [191, 191, 191],
#         [182, 182, 182]],
#
#        [[135, 135, 135],
#         [134, 134, 134],
#         [134, 134, 134],
#         ...,
#         [180, 180, 180],
#         [193, 193, 193],
#         [180, 180, 180]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_026.bmp'})
# source1_027.bmp
# ('wings/source1_027.bmp', {'image': array([[[145, 145, 145],
#         [143, 143, 143],
#         [143, 143, 143],
#         ...,
#         [132, 132, 132],
#         [130, 130, 130],
#         [125, 125, 125]],
#
#        [[146, 146, 146],
#         [145, 145, 145],
#         [146, 146, 146],
#         ...,
#         [128, 128, 128],
#         [127, 127, 127],
#         [122, 122, 122]],
#
#        [[147, 147, 147],
#         [148, 148, 148],
#         [150, 150, 150],
#         ...,
#         [124, 124, 124],
#         [122, 122, 122],
#         [117, 117, 117]],
#
#        ...,
#
#        [[136, 136, 136],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [179, 179, 179],
#         [191, 191, 191],
#         [182, 182, 182]],
#
#        [[137, 137, 137],
#         [134, 134, 134],
#         [136, 136, 136],
#         ...,
#         [180, 180, 180],
#         [186, 186, 186],
#         [186, 186, 186]],
#
#        [[137, 137, 137],
#         [134, 134, 134],
#         [137, 137, 137],
#         ...,
#         [180, 180, 180],
#         [186, 186, 186],
#         [185, 185, 185]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_027.bmp'})
# source1_028.bmp
# ('wings/source1_028.bmp', {'image': array([[[147, 147, 147],
#         [147, 147, 147],
#         [146, 146, 146],
#         ...,
#         [132, 132, 132],
#         [129, 129, 129],
#         [124, 124, 124]],
#
#        [[146, 146, 146],
#         [146, 146, 146],
#         [147, 147, 147],
#         ...,
#         [127, 127, 127],
#         [123, 123, 123],
#         [122, 122, 122]],
#
#        [[145, 145, 145],
#         [147, 147, 147],
#         [148, 148, 148],
#         ...,
#         [117, 117, 117],
#         [117, 117, 117],
#         [119, 119, 119]],
#
#        ...,
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [180, 180, 180],
#         [187, 187, 187],
#         [176, 176, 176]],
#
#        [[139, 139, 139],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [176, 176, 176],
#         [186, 186, 186],
#         [183, 183, 183]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [137, 137, 137],
#         ...,
#         [175, 175, 175],
#         [185, 185, 185],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_028.bmp'})
# source1_029.bmp
# ('wings/source1_029.bmp', {'image': array([[[139, 139, 139],
#         [143, 143, 143],
#         [144, 144, 144],
#         ...,
#         [133, 133, 133],
#         [127, 127, 127],
#         [123, 123, 123]],
#
#        [[141, 141, 141],
#         [146, 146, 146],
#         [148, 148, 148],
#         ...,
#         [129, 129, 129],
#         [122, 122, 122],
#         [119, 119, 119]],
#
#        [[146, 146, 146],
#         [153, 153, 153],
#         [155, 155, 155],
#         ...,
#         [124, 124, 124],
#         [121, 121, 121],
#         [119, 119, 119]],
#
#        ...,
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [138, 138, 138],
#         ...,
#         [180, 180, 180],
#         [183, 183, 183],
#         [178, 178, 178]],
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [182, 182, 182],
#         [184, 184, 184]],
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [135, 135, 135],
#         ...,
#         [182, 182, 182],
#         [183, 183, 183],
#         [184, 184, 184]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_029.bmp'})
# source1_030.bmp
# ('wings/source1_030.bmp', {'image': array([[[141, 141, 141],
#         [143, 143, 143],
#         [145, 145, 145],
#         ...,
#         [134, 134, 134],
#         [131, 131, 131],
#         [125, 125, 125]],
#
#        [[142, 142, 142],
#         [146, 146, 146],
#         [149, 149, 149],
#         ...,
#         [129, 129, 129],
#         [127, 127, 127],
#         [119, 119, 119]],
#
#        [[146, 146, 146],
#         [151, 151, 151],
#         [152, 152, 152],
#         ...,
#         [128, 128, 128],
#         [130, 130, 130],
#         [121, 121, 121]],
#
#        ...,
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [179, 179, 179],
#         [186, 186, 186],
#         [176, 176, 176]],
#
#        [[136, 136, 136],
#         [134, 134, 134],
#         [134, 134, 134],
#         ...,
#         [181, 181, 181],
#         [183, 183, 183],
#         [179, 179, 179]],
#
#        [[138, 138, 138],
#         [136, 136, 136],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [185, 185, 185],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_030.bmp'})
# source1_031.bmp
# ('wings/source1_031.bmp', {'image': array([[[140, 140, 140],
#         [143, 143, 143],
#         [146, 146, 146],
#         ...,
#         [135, 135, 135],
#         [135, 135, 135],
#         [127, 127, 127]],
#
#        [[141, 141, 141],
#         [146, 146, 146],
#         [149, 149, 149],
#         ...,
#         [129, 129, 129],
#         [126, 126, 126],
#         [123, 123, 123]],
#
#        [[143, 143, 143],
#         [150, 150, 150],
#         [154, 154, 154],
#         ...,
#         [125, 125, 125],
#         [118, 118, 118],
#         [116, 116, 116]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [178, 178, 178],
#         [186, 186, 186],
#         [178, 178, 178]],
#
#        [[135, 135, 135],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [178, 178, 178],
#         [187, 187, 187],
#         [177, 177, 177]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [177, 177, 177],
#         [186, 186, 186],
#         [177, 177, 177]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_031.bmp'})
# source1_032.bmp
# ('wings/source1_032.bmp', {'image': array([[[140, 140, 140],
#         [140, 140, 140],
#         [142, 142, 142],
#         ...,
#         [132, 132, 132],
#         [131, 131, 131],
#         [130, 130, 130]],
#
#        [[142, 142, 142],
#         [143, 143, 143],
#         [145, 145, 145],
#         ...,
#         [127, 127, 127],
#         [126, 126, 126],
#         [124, 124, 124]],
#
#        [[147, 147, 147],
#         [148, 148, 148],
#         [150, 150, 150],
#         ...,
#         [126, 126, 126],
#         [125, 125, 125],
#         [123, 123, 123]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [180, 180, 180],
#         [182, 182, 182],
#         [179, 179, 179]],
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [181, 181, 181],
#         [190, 190, 190],
#         [183, 183, 183]],
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [181, 181, 181],
#         [189, 189, 189],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_032.bmp'})
# source1_033.bmp
# ('wings/source1_033.bmp', {'image': array([[[143, 143, 143],
#         [146, 146, 146],
#         [147, 147, 147],
#         ...,
#         [136, 136, 136],
#         [131, 131, 131],
#         [124, 124, 124]],
#
#        [[141, 141, 141],
#         [146, 146, 146],
#         [149, 149, 149],
#         ...,
#         [128, 128, 128],
#         [126, 126, 126],
#         [121, 121, 121]],
#
#        [[143, 143, 143],
#         [150, 150, 150],
#         [153, 153, 153],
#         ...,
#         [124, 124, 124],
#         [125, 125, 125],
#         [123, 123, 123]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [184, 184, 184],
#         [184, 184, 184],
#         [182, 182, 182]],
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [181, 181, 181],
#         [185, 185, 185],
#         [181, 181, 181]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [182, 182, 182],
#         [186, 186, 186],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_033.bmp'})
# source1_034.bmp
# ('wings/source1_034.bmp', {'image': array([[[143, 143, 143],
#         [148, 148, 148],
#         [151, 151, 151],
#         ...,
#         [134, 134, 134],
#         [131, 131, 131],
#         [127, 127, 127]],
#
#        [[140, 140, 140],
#         [146, 146, 146],
#         [149, 149, 149],
#         ...,
#         [133, 133, 133],
#         [128, 128, 128],
#         [123, 123, 123]],
#
#        [[143, 143, 143],
#         [149, 149, 149],
#         [151, 151, 151],
#         ...,
#         [121, 121, 121],
#         [116, 116, 116],
#         [113, 113, 113]],
#
#        ...,
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [181, 181, 181],
#         [184, 184, 184],
#         [179, 179, 179]],
#
#        [[136, 136, 136],
#         [135, 135, 135],
#         [138, 138, 138],
#         ...,
#         [182, 182, 182],
#         [184, 184, 184],
#         [184, 184, 184]],
#
#        [[136, 136, 136],
#         [135, 135, 135],
#         [138, 138, 138],
#         ...,
#         [180, 180, 180],
#         [183, 183, 183],
#         [184, 184, 184]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_034.bmp'})
# source1_035.bmp
# ('wings/source1_035.bmp', {'image': array([[[140, 140, 140],
#         [145, 145, 145],
#         [148, 148, 148],
#         ...,
#         [129, 129, 129],
#         [131, 131, 131],
#         [127, 127, 127]],
#
#        [[136, 136, 136],
#         [143, 143, 143],
#         [148, 148, 148],
#         ...,
#         [131, 131, 131],
#         [126, 126, 126],
#         [122, 122, 122]],
#
#        [[142, 142, 142],
#         [150, 150, 150],
#         [153, 153, 153],
#         ...,
#         [124, 124, 124],
#         [117, 117, 117],
#         [114, 114, 114]],
#
#        ...,
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [181, 181, 181],
#         [189, 189, 189],
#         [183, 183, 183]],
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [179, 179, 179],
#         [188, 188, 188],
#         [184, 184, 184]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [178, 178, 178],
#         [187, 187, 187],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_035.bmp'})
# source1_036.bmp
# ('wings/source1_036.bmp', {'image': array([[[145, 145, 145],
#         [147, 147, 147],
#         [148, 148, 148],
#         ...,
#         [132, 132, 132],
#         [126, 126, 126],
#         [127, 127, 127]],
#
#        [[146, 146, 146],
#         [148, 148, 148],
#         [149, 149, 149],
#         ...,
#         [129, 129, 129],
#         [123, 123, 123],
#         [124, 124, 124]],
#
#        [[147, 147, 147],
#         [150, 150, 150],
#         [149, 149, 149],
#         ...,
#         [124, 124, 124],
#         [120, 120, 120],
#         [117, 117, 117]],
#
#        ...,
#
#        [[139, 139, 139],
#         [138, 138, 138],
#         [136, 136, 136],
#         ...,
#         [181, 181, 181],
#         [185, 185, 185],
#         [178, 178, 178]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [183, 183, 183],
#         [185, 185, 185],
#         [182, 182, 182]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [182, 182, 182],
#         [186, 186, 186],
#         [184, 184, 184]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_036.bmp'})
# source1_037.bmp
# ('wings/source1_037.bmp', {'image': array([[[139, 139, 139],
#         [144, 144, 144],
#         [147, 147, 147],
#         ...,
#         [135, 135, 135],
#         [129, 129, 129],
#         [124, 124, 124]],
#
#        [[141, 141, 141],
#         [145, 145, 145],
#         [146, 146, 146],
#         ...,
#         [127, 127, 127],
#         [125, 125, 125],
#         [121, 121, 121]],
#
#        [[146, 146, 146],
#         [149, 149, 149],
#         [149, 149, 149],
#         ...,
#         [121, 121, 121],
#         [123, 123, 123],
#         [119, 119, 119]],
#
#        ...,
#
#        [[137, 137, 137],
#         [138, 138, 138],
#         [139, 139, 139],
#         ...,
#         [182, 182, 182],
#         [186, 186, 186],
#         [180, 180, 180]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [179, 179, 179],
#         [183, 183, 183],
#         [177, 177, 177]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [181, 181, 181],
#         [185, 185, 185],
#         [178, 178, 178]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_037.bmp'})
# source1_038.bmp
# ('wings/source1_038.bmp', {'image': array([[[144, 144, 144],
#         [146, 146, 146],
#         [147, 147, 147],
#         ...,
#         [131, 131, 131],
#         [129, 129, 129],
#         [130, 130, 130]],
#
#        [[143, 143, 143],
#         [147, 147, 147],
#         [148, 148, 148],
#         ...,
#         [128, 128, 128],
#         [123, 123, 123],
#         [123, 123, 123]],
#
#        [[144, 144, 144],
#         [149, 149, 149],
#         [151, 151, 151],
#         ...,
#         [127, 127, 127],
#         [122, 122, 122],
#         [120, 120, 120]],
#
#        ...,
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [182, 182, 182],
#         [187, 187, 187],
#         [184, 184, 184]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [180, 180, 180],
#         [186, 186, 186],
#         [186, 186, 186]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [179, 179, 179],
#         [185, 185, 185],
#         [184, 184, 184]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_038.bmp'})
# source1_039.bmp
# ('wings/source1_039.bmp', {'image': array([[[145, 145, 145],
#         [145, 145, 145],
#         [144, 144, 144],
#         ...,
#         [135, 135, 135],
#         [131, 131, 131],
#         [124, 124, 124]],
#
#        [[145, 145, 145],
#         [147, 147, 147],
#         [146, 146, 146],
#         ...,
#         [130, 130, 130],
#         [128, 128, 128],
#         [124, 124, 124]],
#
#        [[147, 147, 147],
#         [150, 150, 150],
#         [150, 150, 150],
#         ...,
#         [123, 123, 123],
#         [123, 123, 123],
#         [122, 122, 122]],
#
#        ...,
#
#        [[135, 135, 135],
#         [135, 135, 135],
#         [135, 135, 135],
#         ...,
#         [188, 188, 188],
#         [190, 190, 190],
#         [184, 184, 184]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [181, 181, 181],
#         [187, 187, 187],
#         [187, 187, 187]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [181, 181, 181],
#         [187, 187, 187],
#         [186, 186, 186]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_039.bmp'})
# source1_040.bmp
# ('wings/source1_040.bmp', {'image': array([[[143, 143, 143],
#         [142, 142, 142],
#         [145, 145, 145],
#         ...,
#         [136, 136, 136],
#         [130, 130, 130],
#         [124, 124, 124]],
#
#        [[144, 144, 144],
#         [144, 144, 144],
#         [147, 147, 147],
#         ...,
#         [131, 131, 131],
#         [125, 125, 125],
#         [118, 118, 118]],
#
#        [[146, 146, 146],
#         [148, 148, 148],
#         [151, 151, 151],
#         ...,
#         [125, 125, 125],
#         [123, 123, 123],
#         [118, 118, 118]],
#
#        ...,
#
#        [[140, 140, 140],
#         [139, 139, 139],
#         [137, 137, 137],
#         ...,
#         [181, 181, 181],
#         [185, 185, 185],
#         [179, 179, 179]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [179, 179, 179],
#         [183, 183, 183],
#         [176, 176, 176]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [180, 180, 180],
#         [184, 184, 184],
#         [177, 177, 177]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_040.bmp'})
# source1_041.bmp
# ('wings/source1_041.bmp', {'image': array([[[141, 141, 141],
#         [143, 143, 143],
#         [145, 145, 145],
#         ...,
#         [135, 135, 135],
#         [134, 134, 134],
#         [129, 129, 129]],
#
#        [[144, 144, 144],
#         [147, 147, 147],
#         [148, 148, 148],
#         ...,
#         [131, 131, 131],
#         [129, 129, 129],
#         [123, 123, 123]],
#
#        [[148, 148, 148],
#         [152, 152, 152],
#         [153, 153, 153],
#         ...,
#         [119, 119, 119],
#         [116, 116, 116],
#         [114, 114, 114]],
#
#        ...,
#
#        [[136, 136, 136],
#         [137, 137, 137],
#         [138, 138, 138],
#         ...,
#         [181, 181, 181],
#         [188, 188, 188],
#         [180, 180, 180]],
#
#        [[138, 138, 138],
#         [138, 138, 138],
#         [138, 138, 138],
#         ...,
#         [180, 180, 180],
#         [183, 183, 183],
#         [176, 176, 176]],
#
#        [[139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139],
#         ...,
#         [179, 179, 179],
#         [185, 185, 185],
#         [179, 179, 179]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_041.bmp'})
# source1_042.bmp
# ('wings/source1_042.bmp', {'image': array([[[146, 146, 146],
#         [148, 148, 148],
#         [150, 150, 150],
#         ...,
#         [137, 137, 137],
#         [132, 132, 132],
#         [127, 127, 127]],
#
#        [[146, 146, 146],
#         [148, 148, 148],
#         [151, 151, 151],
#         ...,
#         [125, 125, 125],
#         [120, 120, 120],
#         [117, 117, 117]],
#
#        [[145, 145, 145],
#         [147, 147, 147],
#         [151, 151, 151],
#         ...,
#         [120, 120, 120],
#         [115, 115, 115],
#         [114, 114, 114]],
#
#        ...,
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [179, 179, 179],
#         [183, 183, 183],
#         [180, 180, 180]],
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [135, 135, 135],
#         ...,
#         [178, 178, 178],
#         [187, 187, 187],
#         [180, 180, 180]],
#
#        [[140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140],
#         ...,
#         [181, 181, 181],
#         [190, 190, 190],
#         [183, 183, 183]]], dtype=uint8), 'label': 'wings', 'filename': 'source1_042.bmp'})
# source1_043.bmp
# ('wings/source1_043.bmp', {'image': array([[[146, 146, 146],
#         [144, 144, 144],
#         [145, 145, 145],
#         ...,
#         [134, 134, 134],
#         [133, 133, 133],
#         [128, 128, 128]],
#
#        [[147, 147, 147],
#         [144, 144, 144],
#         [145, 145, 145],
#         ...,
#         [126, 126, 126],
#         [121, 121, 121],
#         [117, 117, 117]],
#
#        [[148, 148, 148],
#         [146, 146, 146],
#         [149, 149, 149],
#         ...,
#         [123, 123, 123],
#         [120, 120, 120],
#         [115, 115, 115]],
#
#        ...,
#
#        [[136, 136, 136],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [180, 180, 180],
#         [179, 179, 179],
#         [181, 181, 181]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [176, 176, 176],
#         [186, 186, 186],
#         [177, 177, 177]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
# ...
#         ...,
#         [182, 182, 182],
#         [181, 181, 181],
#         [181, 181, 181]],
#
#        [[109, 109, 109],
#         [110, 110, 110],
#         [112, 112, 112],
#         ...,
#         [186, 186, 186],
#         [185, 185, 185],
#         [185, 185, 185]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_302.bmp'})
# source3_303.bmp
# ('wings/source3_303.bmp', {'image': array([[[136, 136, 136],
#         [143, 143, 143],
#         [147, 147, 147],
#         ...,
#         [139, 139, 139],
#         [146, 146, 146],
#         [141, 141, 141]],
#
#        [[138, 138, 138],
#         [140, 140, 140],
#         [140, 140, 140],
#         ...,
#         [114, 114, 114],
#         [121, 121, 121],
#         [116, 116, 116]],
#
#        [[139, 139, 139],
#         [136, 136, 136],
#         [131, 131, 131],
#         ...,
#         [ 86,  86,  86],
#         [ 87,  87,  87],
#         [ 87,  87,  87]],
#
#        ...,
#
#        [[111, 111, 111],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [183, 183, 183],
#         [182, 182, 182],
#         [182, 182, 182]],
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [177, 177, 177],
#         [177, 177, 177],
#         [177, 177, 177]],
#
#        [[113, 113, 113],
#         [112, 112, 112],
#         [111, 111, 111],
#         ...,
#         [185, 185, 185],
#         [185, 185, 185],
#         [185, 185, 185]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_303.bmp'})
# source3_304.bmp
# ('wings/source3_304.bmp', {'image': array([[[142, 142, 142],
#         [137, 137, 137],
#         [143, 143, 143],
#         ...,
#         [143, 143, 143],
#         [151, 151, 151],
#         [146, 146, 146]],
#
#        [[143, 143, 143],
#         [137, 137, 137],
#         [141, 141, 141],
#         ...,
#         [121, 121, 121],
#         [122, 122, 122],
#         [114, 114, 114]],
#
#        [[140, 140, 140],
#         [131, 131, 131],
#         [134, 134, 134],
#         ...,
#         [ 93,  93,  93],
#         [ 92,  92,  92],
#         [ 91,  91,  91]],
#
#        ...,
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [181, 181, 181],
#         [181, 181, 181],
#         [181, 181, 181]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [183, 183, 183],
#         [183, 183, 183],
#         [183, 183, 183]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [185, 185, 185],
#         [184, 184, 184],
#         [184, 184, 184]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_304.bmp'})
# source3_305.bmp
# ('wings/source3_305.bmp', {'image': array([[[142, 142, 142],
#         [147, 147, 147],
#         [149, 149, 149],
#         ...,
#         [129, 129, 129],
#         [143, 143, 143],
#         [154, 154, 154]],
#
#        [[142, 142, 142],
#         [145, 145, 145],
#         [144, 144, 144],
#         ...,
#         [118, 118, 118],
#         [120, 120, 120],
#         [113, 113, 113]],
#
#        [[140, 140, 140],
#         [136, 136, 136],
#         [133, 133, 133],
#         ...,
#         [ 84,  84,  84],
#         [ 81,  81,  81],
#         [ 81,  81,  81]],
#
#        ...,
#
#        [[110, 110, 110],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [184, 184, 184],
#         [183, 183, 183],
#         [180, 180, 180]],
#
#        [[110, 110, 110],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [180, 180, 180],
#         [180, 180, 180],
#         [180, 180, 180]],
#
#        [[110, 110, 110],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [182, 182, 182],
#         [182, 182, 182],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_305.bmp'})
# source3_306.bmp
# ('wings/source3_306.bmp', {'image': array([[[144, 144, 144],
#         [142, 142, 142],
#         [146, 146, 146],
#         ...,
#         [133, 133, 133],
#         [141, 141, 141],
#         [142, 142, 142]],
#
#        [[148, 148, 148],
#         [144, 144, 144],
#         [145, 145, 145],
#         ...,
#         [116, 116, 116],
#         [122, 122, 122],
#         [115, 115, 115]],
#
#        [[145, 145, 145],
#         [139, 139, 139],
#         [137, 137, 137],
#         ...,
#         [ 92,  92,  92],
#         [ 93,  93,  93],
#         [ 88,  88,  88]],
#
#        ...,
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [181, 181, 181],
#         [180, 180, 180],
#         [179, 179, 179]],
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [182, 182, 182],
#         [182, 182, 182],
#         [181, 181, 181]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [184, 184, 184],
#         [183, 183, 183],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_306.bmp'})
# source3_307.bmp
# ('wings/source3_307.bmp', {'image': array([[[153, 153, 153],
#         [144, 144, 144],
#         [145, 145, 145],
#         ...,
#         [130, 130, 130],
#         [143, 143, 143],
#         [152, 152, 152]],
#
#        [[151, 151, 151],
#         [148, 148, 148],
#         [148, 148, 148],
#         ...,
#         [118, 118, 118],
#         [124, 124, 124],
#         [119, 119, 119]],
#
#        [[138, 138, 138],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [ 82,  82,  82],
#         [ 83,  83,  83],
#         [ 89,  89,  89]],
#
#        ...,
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [179, 179, 179],
#         [178, 178, 178],
#         [177, 177, 177]],
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [180, 180, 180],
#         [179, 179, 179],
#         [179, 179, 179]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [182, 182, 182],
#         [181, 181, 181],
#         [180, 180, 180]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_307.bmp'})
# source3_308.bmp
# ('wings/source3_308.bmp', {'image': array([[[146, 146, 146],
#         [142, 142, 142],
#         [149, 149, 149],
#         ...,
#         [143, 143, 143],
#         [155, 155, 155],
#         [146, 146, 146]],
#
#        [[145, 145, 145],
#         [140, 140, 140],
#         [145, 145, 145],
#         ...,
#         [119, 119, 119],
#         [120, 120, 120],
#         [110, 110, 110]],
#
#        [[143, 143, 143],
#         [136, 136, 136],
#         [139, 139, 139],
#         ...,
#         [ 78,  78,  78],
#         [ 82,  82,  82],
#         [ 87,  87,  87]],
#
#        ...,
#
#        [[111, 111, 111],
#         [110, 110, 110],
#         [110, 110, 110],
#         ...,
#         [182, 182, 182],
#         [180, 180, 180],
#         [179, 179, 179]],
#
#        [[111, 111, 111],
#         [110, 110, 110],
#         [110, 110, 110],
#         ...,
#         [180, 180, 180],
#         [180, 180, 180],
#         [180, 180, 180]],
#
#        [[113, 113, 113],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [183, 183, 183],
#         [183, 183, 183],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_308.bmp'})
# source3_309.bmp
# ('wings/source3_309.bmp', {'image': array([[[138, 138, 138],
#         [146, 146, 146],
#         [147, 147, 147],
#         ...,
#         [132, 132, 132],
#         [144, 144, 144],
#         [148, 148, 148]],
#
#        [[138, 138, 138],
#         [141, 141, 141],
#         [140, 140, 140],
#         ...,
#         [121, 121, 121],
#         [128, 128, 128],
#         [118, 118, 118]],
#
#        [[138, 138, 138],
#         [135, 135, 135],
#         [133, 133, 133],
#         ...,
#         [ 80,  80,  80],
#         [ 83,  83,  83],
#         [ 81,  81,  81]],
#
#        ...,
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [179, 179, 179],
#         [179, 179, 179],
#         [179, 179, 179]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [181, 181, 181],
#         [181, 181, 181],
#         [181, 181, 181]],
#
#        [[111, 111, 111],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [182, 182, 182],
#         [182, 182, 182],
#         [183, 183, 183]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_309.bmp'})
# source3_310.bmp
# ('wings/source3_310.bmp', {'image': array([[[146, 146, 146],
#         [151, 151, 151],
#         [146, 146, 146],
#         ...,
#         [134, 134, 134],
#         [149, 149, 149],
#         [150, 150, 150]],
#
#        [[145, 145, 145],
#         [145, 145, 145],
#         [139, 139, 139],
#         ...,
#         [126, 126, 126],
#         [129, 129, 129],
#         [116, 116, 116]],
#
#        [[138, 138, 138],
#         [135, 135, 135],
#         [128, 128, 128],
#         ...,
#         [ 88,  88,  88],
#         [ 88,  88,  88],
#         [ 86,  86,  86]],
#
#        ...,
#
#        [[111, 111, 111],
#         [113, 113, 113],
#         [113, 113, 113],
#         ...,
#         [183, 183, 183],
#         [183, 183, 183],
#         [183, 183, 183]],
#
#        [[111, 111, 111],
#         [113, 113, 113],
#         [113, 113, 113],
#         ...,
#         [177, 177, 177],
#         [177, 177, 177],
#         [176, 176, 176]],
#
#        [[111, 111, 111],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [183, 183, 183],
#         [182, 182, 182],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_310.bmp'})
# source3_311.bmp
# ('wings/source3_311.bmp', {'image': array([[[143, 143, 143],
#         [145, 145, 145],
#         [148, 148, 148],
#         ...,
#         [142, 142, 142],
#         [149, 149, 149],
#         [150, 150, 150]],
#
#        [[141, 141, 141],
#         [138, 138, 138],
#         [141, 141, 141],
#         ...,
#         [117, 117, 117],
#         [122, 122, 122],
#         [113, 113, 113]],
#
#        [[139, 139, 139],
#         [131, 131, 131],
#         [134, 134, 134],
#         ...,
#         [ 84,  84,  84],
#         [ 87,  87,  87],
#         [ 86,  86,  86]],
#
#        ...,
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [183, 183, 183],
#         [181, 181, 181],
#         [180, 180, 180]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [179, 179, 179],
#         [179, 179, 179],
#         [180, 180, 180]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [181, 181, 181],
#         [182, 182, 182],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_311.bmp'})
# source3_312.bmp
# ('wings/source3_312.bmp', {'image': array([[[143, 143, 143],
#         [147, 147, 147],
#         [148, 148, 148],
#         ...,
#         [129, 129, 129],
#         [139, 139, 139],
#         [143, 143, 143]],
#
#        [[145, 145, 145],
#         [145, 145, 145],
#         [144, 144, 144],
#         ...,
#         [120, 120, 120],
#         [125, 125, 125],
#         [117, 117, 117]],
#
#        [[139, 139, 139],
#         [136, 136, 136],
#         [136, 136, 136],
#         ...,
#         [ 92,  92,  92],
#         [ 92,  92,  92],
#         [ 88,  88,  88]],
#
#        ...,
#
#        [[111, 111, 111],
#         [110, 110, 110],
#         [110, 110, 110],
#         ...,
#         [182, 182, 182],
#         [181, 181, 181],
#         [181, 181, 181]],
#
#        [[111, 111, 111],
#         [110, 110, 110],
#         [110, 110, 110],
#         ...,
#         [176, 176, 176],
#         [176, 176, 176],
#         [176, 176, 176]],
#
#        [[111, 111, 111],
#         [110, 110, 110],
#         [110, 110, 110],
#         ...,
#         [184, 184, 184],
#         [184, 184, 184],
#         [184, 184, 184]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_312.bmp'})
# source3_313.bmp
# ('wings/source3_313.bmp', {'image': array([[[144, 144, 144],
#         [137, 137, 137],
#         [139, 139, 139],
#         ...,
#         [133, 133, 133],
#         [144, 144, 144],
#         [142, 142, 142]],
#
#        [[141, 141, 141],
#         [135, 135, 135],
#         [137, 137, 137],
#         ...,
#         [118, 118, 118],
#         [126, 126, 126],
#         [117, 117, 117]],
#
#        [[136, 136, 136],
#         [133, 133, 133],
#         [135, 135, 135],
#         ...,
#         [ 92,  92,  92],
#         [ 85,  85,  85],
#         [ 81,  81,  81]],
#
#        ...,
#
#        [[110, 110, 110],
#         [113, 113, 113],
#         [113, 113, 113],
#         ...,
#         [182, 182, 182],
#         [181, 181, 181],
#         [179, 179, 179]],
#
#        [[110, 110, 110],
#         [113, 113, 113],
#         [113, 113, 113],
#         ...,
#         [178, 178, 178],
#         [178, 178, 178],
#         [179, 179, 179]],
#
#        [[110, 110, 110],
#         [113, 113, 113],
#         [113, 113, 113],
#         ...,
#         [180, 180, 180],
#         [180, 180, 180],
#         [181, 181, 181]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_313.bmp'})
# source3_314.bmp
# ('wings/source3_314.bmp', {'image': array([[[148, 148, 148],
#         [141, 141, 141],
#         [136, 136, 136],
#         ...,
#         [124, 124, 124],
#         [137, 137, 137],
#         [152, 152, 152]],
#
#        [[149, 149, 149],
#         [139, 139, 139],
#         [130, 130, 130],
#         ...,
#         [124, 124, 124],
#         [127, 127, 127],
#         [122, 122, 122]],
#
#        [[149, 149, 149],
#         [137, 137, 137],
#         [125, 125, 125],
#         ...,
#         [ 90,  90,  90],
#         [ 86,  86,  86],
#         [ 83,  83,  83]],
#
#        ...,
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [183, 183, 183],
#         [182, 182, 182],
#         [182, 182, 182]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [177, 177, 177],
#         [178, 178, 178],
#         [178, 178, 178]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [185, 185, 185],
#         [186, 186, 186],
#         [187, 187, 187]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_314.bmp'})
# source3_315.bmp
# ('wings/source3_315.bmp', {'image': array([[[145, 145, 145],
#         [146, 146, 146],
#         [144, 144, 144],
#         ...,
#         [123, 123, 123],
#         [145, 145, 145],
#         [146, 146, 146]],
#
#        [[142, 142, 142],
#         [144, 144, 144],
#         [140, 140, 140],
#         ...,
#         [120, 120, 120],
#         [132, 132, 132],
#         [120, 120, 120]],
#
#        [[140, 140, 140],
#         [142, 142, 142],
#         [136, 136, 136],
#         ...,
#         [ 92,  92,  92],
#         [ 94,  94,  94],
#         [ 86,  86,  86]],
#
#        ...,
#
#        [[110, 110, 110],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [181, 181, 181],
#         [180, 180, 180],
#         [178, 178, 178]],
#
#        [[110, 110, 110],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [179, 179, 179],
#         [179, 179, 179],
#         [180, 180, 180]],
#
#        [[110, 110, 110],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [183, 183, 183],
#         [181, 181, 181],
#         [180, 180, 180]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_315.bmp'})
# source3_316.bmp
# ('wings/source3_316.bmp', {'image': array([[[148, 148, 148],
#         [152, 152, 152],
#         [148, 148, 148],
#         ...,
#         [127, 127, 127],
#         [147, 147, 147],
#         [156, 156, 156]],
#
#        [[148, 148, 148],
#         [146, 146, 146],
#         [141, 141, 141],
#         ...,
#         [120, 120, 120],
#         [128, 128, 128],
#         [119, 119, 119]],
#
#        [[139, 139, 139],
#         [134, 134, 134],
#         [133, 133, 133],
#         ...,
#         [ 83,  83,  83],
#         [ 81,  81,  81],
#         [ 78,  78,  78]],
#
#        ...,
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [180, 180, 180],
#         [179, 179, 179],
#         [178, 178, 178]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [179, 179, 179],
#         [177, 177, 177],
#         [176, 176, 176]],
#
#        [[111, 111, 111],
#         [111, 111, 111],
#         [111, 111, 111],
#         ...,
#         [183, 183, 183],
#         [182, 182, 182],
#         [182, 182, 182]]], dtype=uint8), 'label': 'wings', 'filename': 'source3_316.bmp'})

# %%
iterator = a.make_one_shot_iterator()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4e124458a112> in <module>
# ----> 1 iterator = a.make_one_shot_iterator()
#
# AttributeError: 'generator' object has no attribute 'make_one_shot_iterator'

# %%
q = a._generate_examples('./')

# %%
for i in q:
    print(i)
